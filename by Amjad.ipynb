# %%
import pandas as pd 
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import arabic_reshaper
from bidi.algorithm import get_display

# %%
df = pd.read_csv(r"C:\Users\hp\Desktop\c1\Bootcamp-Project-2-Data-Analysis\Data\real_state_riyadh.csv")

# %%
df
# Out:
#                Neighbourhood Plannedـtransactionـdetails Detailsـtransaction  \
# 0      10186 فى/ 28/ 7/ 142…                   مخطط/3738            قطعة 176
# 1      10186 فى/ 28/ 7/ 142…                   مخطط/3738            قطعة 178
# 2      10186 فى/ 28/ 7/ 142…                   مخطط/3738            قطعة 180
# 3      10186 فى/ 28/ 7/ 142…                   مخطط/3738            قطعة 182
# 4      10186 فى/ 28/ 7/ 142…                   مخطط/3738            قطعة 184
# ...                      ...                         ...                 ...
# 14264                  هدبان                   مخطط/2837          قطعة 256/2
# 14265                  هدبان                   مخطط/2837          قطعة 257/1
# 14266             وادى العرج                   مخطط/3242         قطعة 1965/2
# 14267                   واسط                   مخطط/3242         قطعة 1544/1
# 14268                   واسط                   مخطط/3242         قطعة 1545/1
#
# ...

# %%
#by Amjad
ddf=pd.read_csv(r"C:\Users\hp\Desktop\c1\Bootcamp-Project-2-Data-Analysis\Data\real_state_riyadh.csv", usecols= ['Neighbourhood'])

# %%
ddf
# Out:
#                Neighbourhood
# 0      10186 فى/ 28/ 7/ 142…
# 1      10186 فى/ 28/ 7/ 142…
# 2      10186 فى/ 28/ 7/ 142…
# 3      10186 فى/ 28/ 7/ 142…
# 4      10186 فى/ 28/ 7/ 142…
# ...                      ...
# 14264                  هدبان
# 14265                  هدبان
# 14266             وادى العرج
# 14267                   واسط
# 14268                   واسط
#
# [14269 rows x 1 columns]

# %%
df.head()
# Out:
#            Neighbourhood Plannedـtransactionـdetails Detailsـtransaction  \
# 0  10186 فى/ 28/ 7/ 142…                   مخطط/3738            قطعة 176
# 1  10186 فى/ 28/ 7/ 142…                   مخطط/3738            قطعة 178
# 2  10186 فى/ 28/ 7/ 142…                   مخطط/3738            قطعة 180
# 3  10186 فى/ 28/ 7/ 142…                   مخطط/3738            قطعة 182
# 4  10186 فى/ 28/ 7/ 142…                   مخطط/3738            قطعة 184
#
#                          Date  transactionـnumber  Total_price    Area  \
# 0  Thursday, 13 January 2022             15906251     834782.0  642.14
# 1  Thursday, 13 January 2022             15906446     780000.0  600.00
# 2  Thursday, 13 January 2022             15906513     780000.0  600.00
# 3  Thursday, 13 January 2022             15906597     780000.0  600.00
# 4  Thursday, 13 January 2022             15906669     772688.0  594.38
#
#   Price_per_meter
# 0         1300.00
# 1         1300.00
# 2         1300.00
# 3         1300.00
# ...

# %%
df= pd.read_csv(Neighbourhood)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df= pd.read_csv(Neighbourhood)
#
# NameError: name 'Neighbourhood' is not defined

# %%
unique_names = []
for name in df['Neighbourhood']:
    if name not in unique_names:
        unique_names.append(name)

for name in unique_names:
    print(name)
# Out:
# 10186 فى/ 28/ 7/ 142…
# 1353 فى/ 20/ 5/ 1413
# 6 / 8 / 2 / 1429
# 667/ 23/ 9/ 1410
# 6868 فى/ 3/ 12/ 1411
# أحد
# أخرى
# ارضة الجو منطقة العز…
# اشبيليا
# الازدهار
# الامانة
# الاندلس
# البايونية
# البديعة
# البرية
# البطحاء
# البيان
# التعاون
# الثقبة
# الجرادية
# الجزيرة
# الجنادرية
# الجهه الغربية
# الحائر
# الحزم
# الحمراء
# الخالدية
# الخليج
# الخويلدية
# الخير
# الدار البيضاء
# الدريهمية
# الرابية
# الراية
# الربوة
# الربيع
# الرحمانية
# الرسالة
# الرفيعة
# الرقيقة
# الرمال
# الروابى
# الروضة
# الريان
# الزاهر
# الزهرة
# الزهور
# السعادة
# السلام
# السلام بسيهات
# السلى
# السليمانية
# السوق
# السويدى
# الشرفية
# الشرق
# الشعلة
# الشعيب
# الشفاء
# الشقة
# الشلهوب
# الشميسى
# الشهداء
# الصالحية
# الصحافة
# الصفاء
# الضباط
# العارض
# العريجاء
# العزيزية
# العقيق
# العلا
# العليا
# العوالي
# العود
# الغدير
# الغروب
# الغنامية
# الفاروق
# الفلاح
# الفيحاء
# الفيصلية
# القادسية
# القاع البارد
# القدس
# القرى
# القيروان
# المحلة بجبل سلا
# المحمدية
# المخروقه
# المربع
# المرسلات
# ...

# %%
df_clean = df[~df['Neighbourhood'].str.contains('\d')]

df_clean
# Out:
#       Neighbourhood Plannedـtransactionـdetails Detailsـtransaction  \
# 15              أحد                   مخطط/2022            قطعة 172
# 16              أحد                   مخطط/2022            قطعة 173
# 17              أحد                   مخطط/2485            قطعة 381
# 18              أحد                   مخطط/3152            قطعة 215
# 19             أخرى                   مخطط/1669           قطعة بدون
# ...             ...                         ...                 ...
# 14264         هدبان                   مخطط/2837          قطعة 256/2
# 14265         هدبان                   مخطط/2837          قطعة 257/1
# 14266    وادى العرج                   مخطط/3242         قطعة 1965/2
# 14267          واسط                   مخطط/3242         قطعة 1544/1
# 14268          واسط                   مخطط/3242         قطعة 1545/1
#
#                             Date  transactionـnumber  Total_price    Area  \
# 15     Tuesday, 18 January 2022             15942311    1250000.0  600.00
# ...

# %%
df_clean.drop('transactionـnumber', inplace=True, axis=1)
df_clean.drop('Plannedـtransactionـdetails', inplace=True, axis=1)
df_clean
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8404\1934954544.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean.drop('transactionـnumber', inplace=True, axis=1)
# C:\Users\hp\AppData\Local\Temp\ipykernel_8404\1934954544.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean.drop('Plannedـtransactionـdetails', inplace=True, axis=1)
#       Neighbourhood Detailsـtransaction                       Date  \
# 15              أحد            قطعة 172  Tuesday, 18 January 2022
# 16              أحد            قطعة 173  Tuesday, 18 January 2022
# ...

# %%
df_clean['Price_per_meter'] = df_clean['Price_per_meter'].str.replace(',', '')
df_clean['Area'] = df_clean['Area'].str.replace(',', '')
df_clean
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8404\3871690284.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Price_per_meter'] = df_clean['Price_per_meter'].str.replace(',', '')
# C:\Users\hp\AppData\Local\Temp\ipykernel_8404\3871690284.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Area'] = df_clean['Area'].str.replace(',', '')
#       Neighbourhood Detailsـtransaction                       Date  \
# ...

# %%
filtered_df = df_clean.loc[df['Neighbourhood'] == 'الرمال']

# %%
df_clean['Area']=df_clean['Area'].astype(float)
df_clean['Price_per_meter']=df_clean['Price_per_meter'].astype(float)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8404\1892363530.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Area']=df_clean['Area'].astype(float)
# C:\Users\hp\AppData\Local\Temp\ipykernel_8404\1892363530.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Price_per_meter']=df_clean['Price_per_meter'].astype(float)

# %%
df_clean['Total_price'].sum()
# Out:
# 15313490978.0

# %%
df_clean.shape[0]
# Out:
# 14187

# %%
df_clean.isnull().sum()
# Out:
# Neighbourhood          0
# Detailsـtransaction    0
# Date                   0
# Total_price            0
# Area                   0
# Price_per_meter        0
# dtype: int64

# %%
#ignore
#test1=(df.groupby('Neighbourhood')
 #  .agg(lambda x: x.value_counts().loc[x.max()])
  # .reset_index(name='count_max')
#)

# %%
#ignore
#ddf['freq'] = df.groupby('Neighbourhood').transform('count')
#ddf

# %%
count_Neighbourhood_t=df_clean['Neighbourhood'].value_counts()
landss = count_Neighbourhood_t.head().index.tolist()

# Reshape the labels using arabic_reshaper and get_display
reshaped_labels = [get_display(arabic_reshaper.reshape(label)) for label in landss]

count_Neighbourhood_t.head().plot.bar(fontsize=12, color=('tan', 'oldlace'))
plt.title('Top Selling Riyadh Communities Neighbourhood', fontsize=14, weight="bold", color='tan')
plt.xticks(range(len(landss)), reshaped_labels, rotation=45, ha='right')

plt.show()

# %%
ddf['Neighbourhood']=ddf['Neighbourhood'].str.replace('\d+','')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8404\3339735607.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   ddf['Neighbourhood']=ddf['Neighbourhood'].str.replace('\d+','')

# %%
ddf['Neighbourhood']=ddf['Neighbourhood'].replace(['مطار الملك خالد الدولى'], 'بنبان')

# %%
ddf['Neighbourhood']=ddf['Neighbourhood'].replace(['outside Riyadh'],'معكال')

# %%
count_Neighbourhood_t=df_clean['Neighbourhood'].value_counts()
landss = count_Neighbourhood_t.tail(3).index.tolist()

# Reshape the labels using arabic_reshaper and get_display
reshaped_labels = [get_display(arabic_reshaper.reshape(label)) for label in landss]

count_Neighbourhood_t.tail(3).plot.bar(fontsize=12, color=('tan', 'oldlace'))
plt.title('Less Selling Riyadh Communities Neighbourhood', fontsize=14, weight="bold", color='tan')
plt.xticks(range(len(landss)), reshaped_labels, rotation=45, ha='right')

plt.show()

# %%
dedf=pd.read_csv(r"C:\Users\hp\Desktop\c1\Bootcamp-Project-2-Data-Analysis\Data\real_state_riyadh.csv", usecols= ['Total_price','Neighbourhood'])

# %%
dedf
# Out:
#                Neighbourhood  Total_price
# 0      10186 فى/ 28/ 7/ 142…     834782.0
# 1      10186 فى/ 28/ 7/ 142…     780000.0
# 2      10186 فى/ 28/ 7/ 142…     780000.0
# 3      10186 فى/ 28/ 7/ 142…     780000.0
# 4      10186 فى/ 28/ 7/ 142…     772688.0
# ...                      ...          ...
# 14264                  هدبان    2099475.0
# 14265                  هدبان    1959510.0
# 14266             وادى العرج     718750.0
# 14267                   واسط     685000.0
# 14268                   واسط     680000.0
#
# [14269 rows x 2 columns]

# %%
dedf.nlargest(n=5, columns=['Total_price'])
# Out:
#       Neighbourhood  Total_price
# 10130       التعاون   61854100.0
# 11541        العليا   50000000.0
# 12314      الياسمين   50000000.0
# 10223       الخزامى   49000000.0
# 2889           بدون   46251885.0

# %%
df3=pd.read_csv(r"C:\Users\hp\Desktop\c1\Bootcamp-Project-2-Data-Analysis\Data\real_state_riyadh.csv", usecols= ['Total_price','Neighbourhood'], index_col='Neighbourhood')

# %%
df3
# Out:
#                        Total_price
# Neighbourhood
# 10186 فى/ 28/ 7/ 142…     834782.0
# 10186 فى/ 28/ 7/ 142…     780000.0
# 10186 فى/ 28/ 7/ 142…     780000.0
# 10186 فى/ 28/ 7/ 142…     780000.0
# 10186 فى/ 28/ 7/ 142…     772688.0
# ...                            ...
# هدبان                    2099475.0
# هدبان                    1959510.0
# وادى العرج                718750.0
# واسط                      685000.0
# واسط                      680000.0
#
# [14269 rows x 1 columns]

# %%
df3.nlargest(n=4, columns=['Total_price'])
# Out:
#                Total_price
# Neighbourhood
# التعاون         61854100.0
# العليا          50000000.0
# الياسمين        50000000.0
# الخزامى         49000000.0

# %%
neighborhoods = df3.nlargest(n=4, columns=['Total_price']).index.tolist()


reshaped_labels = [get_display(arabic_reshaper.reshape(label)) for label in neighborhoods]

df3.nlargest(n=4, columns=['Total_price']).plot.bar(fontsize=13, color=('tan','wheat'))
plt.title('The most hight price selling of the lands ', fontsize=14, weight="bold", color='tan')
plt.xticks(range(len(neighborhoods)), reshaped_labels, rotation=0, ha='center')
plt.show()
